# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0,20)
y1 = np.random.randint(5,15, 20)
y2 = np.random.randint(3,10, 20)
y3 = np.random.randint(2,8, 20)

plt.stackplot(x, y1, y2, y3)
# Out:
# [<matplotlib.collections.PolyCollection at 0x1776ce1ef10>,
#  <matplotlib.collections.PolyCollection at 0x1776ce38190>,
#  <matplotlib.collections.PolyCollection at 0x1776ce384f0>]
