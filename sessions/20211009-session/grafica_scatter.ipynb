# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(100)
y = np.random.randn(100)
y2 = np.random.randn(100)
z = np.random.randn(100)
w = np.random.randn(100)*100+10

# Cambia paleta de colores
# plt.plasma()
# plt.viridis()
# plt.gray()

plt.scatter(x,y,c=z,s=w,marker="^", cmap="rainbow")
plt.scatter(x,y2,c=z,s=w,marker="p", cmap="plasma")
